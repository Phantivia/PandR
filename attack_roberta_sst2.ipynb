# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import transformers
import json
from pathlib import Path
import torch
from transformers import BertForQuestionAnswering
from torch.utils.data import DataLoader
from transformers import AdamW
from tqdm.auto import tqdm
print("pakages imported")
# Out:
# pakages imported

# %% [markdown]
# MyBertSelfAttention_detect

# %%
BATCH_SIZE = 1
from torch import nn
GRAPH =[]
from torch.nn import Softmax
class MyBertSelfAttention_detect(nn.Module):
    def __init__(self, config):
        super().__init__()
        if config.hidden_size % config.num_attention_heads != 0 and not hasattr(config, "embedding_size"):
            raise ValueError(
                "The hidden size (%d) is not a multiple of the number of attention "
                "heads (%d)" % (config.hidden_size, config.num_attention_heads)
            )

        self.num_attention_heads = config.num_attention_heads
        self.attention_head_size = int(config.hidden_size / config.num_attention_heads)
        self.all_head_size = self.num_attention_heads * self.attention_head_size

        self.query = nn.Linear(config.hidden_size, self.all_head_size)
        self.key = nn.Linear(config.hidden_size, self.all_head_size)
        self.value = nn.Linear(config.hidden_size, self.all_head_size)
        self.config = config
        
        self.perturb_on = False
        self.perturb = None
        self.sofm = Softmax(dim = 0)
        
        self.flag = False
        self.count = 0
#         self.hidden_temp = None

        self.dropout = nn.Dropout(config.attention_probs_dropout_prob)
        self.position_embedding_type = getattr(config, "position_embedding_type", "absolute")
        if self.position_embedding_type == "relative_key" or self.position_embedding_type == "relative_key_query":
            self.max_position_embeddings = config.max_position_embeddings
            self.distance_embedding = nn.Embedding(2 * config.max_position_embeddings - 1, self.attention_head_size)

        self.is_decoder = config.is_decoder
    #modified
    
    def p_init(self, input_length, start_from = None):
        SQRT_NUMEL = (input_length * self.config.hidden_size) ** 0.5
        self.perturb = torch.zeros((BATCH_SIZE, input_length, self.config.hidden_size), device = torch.device('cuda')).uniform_(-INIT_MAG, INIT_MAG)/SQRT_NUMEL
        
        self.perturb[:, 0, : ] = 0.0
        self.perturb[:, -1, :] = 0.0
        
        if start_from is not None:
            self.perturb = (self.perturb + start_from).detach()
            
        self.perturb.requires_grad_()
        
    def p_accu(self, loss, adv_lr, input_length = 5):
        grad = torch.autograd.grad(loss, self.perturb)[0]

        grad[:, 0, :] = 0.0
        grad[:, -1, :] = 0.0
        
        grad = (adv_lr * grad/grad.norm()).detach()
        
        self.perturb = (self.perturb + grad).detach()

        self.perturb.grad = None
        self.perturb.requires_grad_()
        
    ##here
    def transpose_for_scores(self, x):
        new_x_shape = x.size()[:-1] + (self.num_attention_heads, self.attention_head_size)
        x = x.view(*new_x_shape)
        return x.permute(0, 2, 1, 3)

    def forward(
        self,
        hidden_states,
        attention_mask=None,
        head_mask=None,
        encoder_hidden_states=None,
        encoder_attention_mask=None,
        past_key_value=None,
        output_attentions=False,
    ):
        if self.perturb is not None:
            hidden_states = hidden_states + self.perturb
        
        mixed_query_layer = self.query(hidden_states)
        
        
        # If this is instantiated as a cross-attention module, the keys
        # and values come from an encoder; the attention mask needs to be
        # such that the encoder's padding tokens are not attended to.
        is_cross_attention = encoder_hidden_states is not None

        if is_cross_attention and past_key_value is not None:
            # reuse k,v, cross_attentions
            key_layer = past_key_value[0]
            value_layer = past_key_value[1]
            attention_mask = encoder_attention_mask
        elif is_cross_attention:
            key_layer = self.transpose_for_scores(self.key(encoder_hidden_states))
            value_layer = self.transpose_for_scores(self.value(encoder_hidden_states))
            attention_mask = encoder_attention_mask
        elif past_key_value is not None:
            key_layer = self.transpose_for_scores(self.key(hidden_states))
            value_layer = self.transpose_for_scores(self.value(hidden_states))
            key_layer = torch.cat([past_key_value[0], key_layer], dim=2)
            value_layer = torch.cat([past_key_value[1], value_layer], dim=2)
        else:
            key_layer = self.transpose_for_scores(self.key(hidden_states))
            value_layer = self.transpose_for_scores(self.value(hidden_states))

        query_layer = self.transpose_for_scores(mixed_query_layer)

        if self.is_decoder:
            # if cross_attention save Tuple(torch.Tensor, torch.Tensor) of all cross attention key/value_states.
            # Further calls to cross_attention layer can then reuse all cross-attention
            # key/value_states (first "if" case)
            # if uni-directional self-attention (decoder) save Tuple(torch.Tensor, torch.Tensor) of
            # all previous decoder key/value_states. Further calls to uni-directional self-attention
            # can concat previous decoder key/value_states to current projected key/value_states (third "elif" case)
            # if encoder bi-directional self-attention `past_key_value` is always `None`
            past_key_value = (key_layer, value_layer)

        # Take the dot product between "query" and "key" to get the raw attention scores.
        attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))

        if self.position_embedding_type == "relative_key" or self.position_embedding_type == "relative_key_query":
            seq_length = hidden_states.size()[1]
            position_ids_l = torch.arange(seq_length, dtype=torch.long, device=hidden_states.device).view(-1, 1)
            position_ids_r = torch.arange(seq_length, dtype=torch.long, device=hidden_states.device).view(1, -1)
            distance = position_ids_l - position_ids_r
            positional_embedding = self.distance_embedding(distance + self.max_position_embeddings - 1)
            positional_embedding = positional_embedding.to(dtype=query_layer.dtype)  # fp16 compatibility

            if self.position_embedding_type == "relative_key":
                relative_position_scores = torch.einsum("bhld,lrd->bhlr", query_layer, positional_embedding)
                attention_scores = attention_scores + relative_position_scores
            elif self.position_embedding_type == "relative_key_query":
                relative_position_scores_query = torch.einsum("bhld,lrd->bhlr", query_layer, positional_embedding)
                relative_position_scores_key = torch.einsum("bhrd,lrd->bhlr", key_layer, positional_embedding)
                attention_scores = attention_scores + relative_position_scores_query + relative_position_scores_key

        attention_scores = attention_scores / math.sqrt(self.attention_head_size)
            
        if attention_mask is not None:
            # Apply the attention mask is (precomputed for all layers in BertModel forward() function)
            attention_scores = attention_scores + attention_mask

        # Normalize the attention scores to probabilities.
        #modified

        attention_probs = nn.Softmax(dim=-1)(attention_scores)


        # This is actually dropping out entire tokens to attend to, which might
        # seem a bit unusual, but is taken from the original Transformer paper.
        attention_probs = self.dropout(attention_probs)

        # Mask heads if we want to
        if head_mask is not None:
            attention_probs = attention_probs * head_mask

        context_layer = torch.matmul(attention_probs, value_layer)

        context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
        new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
        context_layer = context_layer.view(*new_context_layer_shape)

        outputs = (context_layer, attention_probs) if output_attentions else (context_layer,)

        if self.is_decoder:
            outputs = outputs + (past_key_value,)
        return outputs

# %%
GLUE_TASKS = ["cola", "mnli", "mnli-mm", "mrpc", "qnli", "qqp", "rte", "sst2", "stsb", "wnli"]
task = 'sst2'
model_checkpoint = "roberta-base"
model_state = None

# %%
from datasets import load_dataset, load_metric
import datasets

from transformers import RobertaForSequenceClassification
import math

actual_task = "mnli" if task == "mnli-mm" else task
num_labels = 3 if task.startswith("mnli") else 1 if task=="stsb" else 2
dataset = datasets.DatasetDict.load_from_disk("glue/" + actual_task)

task_to_keys = {    
                "cola": ("sentence", None),
                "mnli": ("premise", "hypothesis"),
                "mnli-mm": ("premise", "hypothesis"),
                "mrpc": ("sentence1", "sentence2"),
                "qnli": ("question", "sentence"),
                "qqp": ("question1", "question2"),
                "rte": ("sentence1", "sentence2"),
                "sst2": ("sentence", None),
                "stsb": ("sentence1", "sentence2"),
                "wnli": ("sentence1", "sentence2"),
            }

sentence1_key, sentence2_key = task_to_keys[task]


from transformers import AutoTokenizer,RobertaForSequenceClassification, AutoModelForSequenceClassification
    
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)

def preprocess_function(examples):
    if sentence2_key is None:
        return tokenizer(examples[sentence1_key], truncation=True)
    return tokenizer(examples[sentence1_key], examples[sentence2_key], truncation=True)

encoded_dataset = dataset.map(preprocess_function, batched=True)
encoded_dataset.set_format("numpy")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=68.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))

# %%
# model = RobertaForSequenceClassification.from_pretrained(model_checkpoint, num_labels = num_labels, mirror = "bfsu")
# torch.save(model.state_dict(),"raw_pretrained_state.pth")

model = torch.load('SST2-robertabase-fullunit-8848.pt')
model.load_state_dict(torch.load("SST2-fullfintuned-robertabase-8848.pth"))
torch.save(model.state_dict(),"temp_state.pth")

for i in model.roberta.encoder.layer:
    p_layer = MyBertSelfAttention_detect(model.config)
    i.attention.self = p_layer

model.load_state_dict(torch.load('temp_state.pth'))
torch.cuda.empty_cache()
if torch.cuda.is_available():
    model.cuda()

# %%
from transformers import AutoModelForMaskedLM
mlm_model = AutoModelForMaskedLM.from_pretrained('roberta-base', mirror = "bfsu")
probe_layer = mlm_model.lm_head
probe_layer.cuda()
# Out:
# RobertaLMHead(
#   (dense): Linear(in_features=768, out_features=768, bias=True)
#   (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   (decoder): Linear(in_features=768, out_features=50265, bias=True)
# )

# %%
victim_model = RobertaForSequenceClassification(model.config)

victim_model.load_state_dict(torch.load("SST2-fullfintuned-robertabase-8848.pth"))
if torch.cuda.is_available():
    victim_model.cuda()

# %%
import tensorflow_hub as hub
import tensorflow as tf
class USE:
    def __init__(self):
        self.embed = hub.load("use")

    def count_use(self, sentence1, sentence2):
        embeddings = self.embed([sentence1, sentence2])

        vector1 = tf.reshape(embeddings[0], [512, 1])
        vector2 = tf.reshape(embeddings[1], [512, 1])

        return tf.matmul(vector1, vector2, transpose_a=True).numpy()[0][0]
use = USE()

# %%
from torch.nn import CrossEntropyLoss, MSELoss
class Prober():
    
    def __init__(self, tokenizer, probe_layer, victim_model):
        self.celoss = CrossEntropyLoss()
        self.tokenizer = tokenizer
        self.probe_layer = probe_layer
        self.victim = victim_model
        
        if torch.cuda.is_available():
            self.probe_layer.cuda()
            
    def decode(self, hidden, origin_ids = None):
        probe = self.probe_layer(hidden)
        
        _probe = probe.detach()
        _probe[:, :,0:4] = 0.0
        #mask token
        _probe[:, :,50264] = 0.0
        
        
        reconstruction_ids = torch.topk(_probe, 1, -1)[1].squeeze(-1)
        
        reconstruction_ids[:, 0] = 1
        reconstruction_ids[:,-1] = 2
        
        if origin_ids is None:
            return reconstruction_ids
        
        origin_ids = origin_ids[:, 1:-1].long().cuda()
        probe = probe[:, 1:-1, :]

        
        decode_loss = self.celoss(probe.reshape(-1, tokenizer.vocab_size), origin_ids.reshape(-1))

        return decode_loss, reconstruction_ids
        
    
    def attack(self, ids, answer_label):
        
        ids = ids.unsqueeze(0).cuda()
        attention_mask = (torch.zeros(ids.shape) + 1).long().cuda()
        
        output = self.victim(input_ids = ids, attention_mask = attention_mask, labels = answer_label)
        logits = output[1]

        adv_answer = logits.argmax(dim = 1)
        
        ids = ids[:, 1:-1]
        reconstruction_tokens = self.tokenizer.batch_decode(ids)
        reconstruction_sentence = self.tokenizer.convert_tokens_to_string(reconstruction_tokens)
#         print(reconstruction_sentence)

#         print(adv_answer,answer_label, "LOGITS: ", logits )
        reconstruction_sentence = None
        
        
        if not adv_answer.equal(answer_label):
            #print("CALL")
            reconstruction_tokens = self.tokenizer.batch_decode(ids)
            reconstruction_sentence = self.tokenizer.convert_tokens_to_string(reconstruction_tokens)
            
        return reconstruction_sentence
    
prober = Prober(tokenizer, probe_layer, victim_model)

# %%
from tqdm import tqdm

LAST_HIDDEN_MAG = 15
def cal_metric(s1, s2):
    _use = use.count_use(s1,s2)
    return _use,0,0

def attack_step(dataset = None, encoded_dataset = None, index = 0, 
                adv_lr = 3e-2, adv_steps = 3, start_layer = 0, prober = None, 
                scheduler = None, SEED = 114514):
    
    encoded_dataset.set_format("numpy")
    
    def model_forward(model, input_ids, attention_mask, labels):
        output = model(input_ids=input_ids, attention_mask=attention_mask, labels = labels, output_hidden_states = True)
        loss = output[0]
        hidden = output[2][HIDDEN_INDEX]
        logits = output[1]
        return loss,logits,hidden
    
    def random_cover(ids):
        import random 
        rindex = random.randint(1, input_length- 2)
        ids[:, rindex] = 50264
        return ids
    
    

    ori_sentence = dataset['validation'][index]['sentence']
    input_ids = torch.tensor(encoded_dataset['validation']['input_ids'][index]).unsqueeze(0)
    attention_mask = torch.tensor(encoded_dataset['validation']['attention_mask'][index]).unsqueeze(0)
    label = torch.tensor(encoded_dataset['validation']['label'][index]).unsqueeze(0).cuda()
    
    #print("LABEL", label)
    correct_test = prober.attack(input_ids[0], label)
    #print(correct_test)
    if correct_test is not None:
        return None
    
    #BATCH SET UP
    input_length = len(input_ids[0])
    ori_input_ids = torch.tensor(input_ids.tolist() * BATCH_SIZE).cuda()
    attention_mask = torch.tensor(attention_mask.tolist() * BATCH_SIZE).cuda()
    batch_labels = torch.tensor(label.tolist() * BATCH_SIZE).cuda()
    
    input_ids = random_cover(ori_input_ids.clone())
    
    p_layer = model.roberta.encoder.layer[start_layer].attention.self
    p_layer.perturb = None
        
    
    successed = False
    query = 0
    pll = 0
    I = 0
    use = 0
    bpstep = 0
    rec_token_acc = 0
    adv_sentence = None
    
    id_base = []
    id_base.append(input_ids.tolist())

    torch.manual_seed(SEED)
    origin_loss, origin_logits, origin_hidden = model_forward(model, input_ids=input_ids, attention_mask=attention_mask, labels = batch_labels)
    reconstruct_ids = prober.decode(origin_hidden)

    rec_token_acc = ((input_ids == reconstruct_ids).sum() / input_ids.numel()).tolist()
    
    for i in reconstruct_ids:
        if not i.tolist() in id_base:
            id_base.append(i.tolist())
            query += 1
            adv_sentence = prober.attack(i, label)
            if adv_sentence is not None:
                use,I,ppl = cal_metric(ori_sentence, adv_sentence)
                #print("USE = ", use)
                if use > USE_GATE:
                    successed = True
                    bpstep = -1
                    successed = True
                    return{
                        'successed': successed,
                        'query': query,
                        'pll': pll,
                        'I': I,
                        'use': use,
                        'bpstep': bpstep,
                        'token_acc': rec_token_acc,
                        'ori_sentence': ori_sentence,
                        'adv_sentence': adv_sentence
                    }

    torch.manual_seed(SEED)
    p_layer.p_init(input_length)
    torch.manual_seed(SEED)
    loss, logits, hidden = model_forward(model, input_ids=input_ids, attention_mask=attention_mask, labels = batch_labels)
    decode_loss, init_ids = prober.decode(hidden, origin_ids = input_ids)
    
    for i in init_ids:
        if not i.tolist() in id_base:
            id_base.append(i.tolist())
            query += 1
            adv_sentence = prober.attack(i, label)
            if adv_sentence is not None:
                use,I,ppl = cal_metric(ori_sentence, adv_sentence)
                if use > USE_GATE:
                    successed = True
                    bpstep = -1
                    successed = True
                    return{
                        'successed': successed,
                        'query': query,
                        'pll': pll,
                        'I': I,
                        'use': use,
                        'bpstep': bpstep,
                        'token_acc': rec_token_acc,
                        'ori_sentence': ori_sentence,
                        'adv_sentence': adv_sentence
                    }



    seg_step = 0
    max_use = 0
    
    for seg_step in range(SEG_STEP):
        lr = adv_lr
        for i in (range(adv_steps)):

            projected = p_layer.p_accu(loss * LOSS_WEIGHT - decode_loss * DECODE_WEIGHT, lr, input_length = input_length)

            torch.manual_seed(SEED)
            loss, logits, hidden =  model_forward(model, input_ids=input_ids, attention_mask=attention_mask, labels = batch_labels)
            decode_loss, p_ids = prober.decode(hidden, origin_ids = input_ids)

            for p_id in p_ids:
                if not p_id.tolist() in id_base:
                    id_base.append(p_id.tolist())
                    query += 1
                    adv_sentence = prober.attack(p_id, label)

                    if adv_sentence is not None:
                        use,I,ppl = cal_metric(ori_sentence, adv_sentence)
#                         print(adv_sentence, " USE = ",use)
                        if use> max_use:
                            max_use = use
                        if use > USE_GATE:
                            successed = True
                            bpstep = seg_step * adv_steps + i
                            successed = True
                            return{
                                'successed': successed,
                                'query': query,
                                'pll': pll,
                                'I': I,
                                'use': use,
                                'bpstep': bpstep,
                                'token_acc': rec_token_acc,
                                'ori_sentence': ori_sentence,
                                'adv_sentence': adv_sentence
                            }
#         print("################RESET!####################", " D_LOSS = ", (loss-origin_loss).norm(), "BASED: ", len(id_base), "Query; ", query)
        input_ids = random_cover(ori_input_ids.clone())
#         print(input_ids.tolist())
        torch.manual_seed(SEED + seg_step)
        p_layer.p_init(input_length, start_from = None)
        loss, logits, hidden = model_forward(model, input_ids=input_ids, attention_mask=attention_mask, labels = batch_labels)
    torch.cuda.empty_cache()
    return{
        'successed': successed,
        'query': query,
        'pll': pll,
        'I': I,
        'use': max_use,
        'bpstep': bpstep,
        'token_acc': rec_token_acc,
        'ori_sentence': ori_sentence,
        'adv_sentence': adv_sentence
    }

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
model.cuda()
import seaborn as sb
import gc

gc.collect()
torch.cuda.empty_cache()
SEG_STEP = 70

HIDDEN_INDEX = 7
INIT_MAG = 1

BATCH_SIZE = 1
USE_GATE = 0.87

SEED = 114514


LOSS_WEIGHT = 1
DECODE_WEIGHT = 0.01


def exp_lr(adv_lr, step):
    if step > 200:
        adv_lr -= 1/400
    return adv_lr

suca = []
alla = []
import random
random.seed(SEED)
for i in tqdm(range(872)):
    gc.collect()
    torch.cuda.empty_cache()
    ret = attack_step(
        dataset = dataset, 
        encoded_dataset = encoded_dataset, 
        index = i, 
        adv_lr = 2,
        adv_steps = 50, 
        start_layer = 0, 
        prober = prober,
        scheduler = None,
        SEED = SEED
        )
#     print(ret)
    if ret is not None:
        if ret['successed']:
            suca.append(ret)
        alla.append(ret)
# Out:
#   0%|          | 0/872 [00:00<?, ?it/s]/mistgpu/site-packages/datasets/formatting/formatting.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return np.array(array, copy=False, **self.np_array_kwargs)
# 100%|██████████| 872/872 [6:31:07<00:00, 26.91s/it]

# %%
torch.save(alla, "alla-sst2-roberta.pt")
import seaborn as sb
stat = {
        'successed': [],
        'query': [],
        'pll': [],
        'I': [],
        'use': [],
        'bpstep': [],
        'token_acc': [],
    }
for key in stat.keys():
    for data in alla:
        stat[key].append(data[key])
    sb.displot(stat[key])
    if key != 'successed':
        stat[key] = np.array(stat[key]).mean()
    else:
        stat[key] = len(suca)/len(alla)
print(stat)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# {'successed': 0.8791208791208791, 'query': 499.1098901098901, 'pll': 0.0, 'I': 0.0, 'use': 0.8903519872198465, 'bpstep': 343.35653235653234, 'token_acc': 0.7102652801262154}

# %%
u = []
bar = 0
alla = torch.load('alla2.pt')
for data in alla:
    u.append(data['use'])
u.sort()
u = np.array(u)
print(u[bar:].mean())
print(len(u[bar:]) / len(u))
# Out:
# 0.8925329
# 1.0

# %%
print(u)
# Out:
# [0.6625543  0.71229255 0.74654174 0.7499329  0.7552591  0.7625301
#  0.7625966  0.78527915 0.7983159  0.80774456 0.8098961  0.8129233
#  0.8130082  0.8200667  0.8226042  0.8240778  0.8310441  0.83758026
#  0.8402927  0.8415998  0.8446654  0.84629416 0.8466169  0.850191
#  0.8503466  0.85129124 0.85159    0.85437256 0.854585   0.85635906
#  0.85774094 0.85973155 0.8598602  0.86039895 0.8617891  0.8621733
#  0.8625554  0.86342    0.8637707  0.86401033 0.8644056  0.8644812
#  0.8656045  0.8658235  0.86618495 0.8662572  0.867081   0.8681741
#  0.86822546 0.86983323 0.87019324 0.8703551  0.8703807  0.8705717
#  0.87068915 0.8706922  0.87072974 0.8708049  0.87086    0.8710199
#  0.8711545  0.8713007  0.8714082  0.8714192  0.8716038  0.87167037
#  0.8718564  0.87190974 0.87194455 0.872175   0.87219626 0.87222373
#  0.87232864 0.87260634 0.87262714 0.8728919  0.8729573  0.8730883
#  0.87310344 0.873252   0.8733068  0.87339014 0.87343615 0.87344366
#  0.87346566 0.87348306 0.873708   0.87377864 0.873877   0.87393683
#  0.8739723  0.8740349  0.87405866 0.87423635 0.8744938  0.8745696
#  0.8745742  0.87469333 0.8747699  0.8748063  0.87492794 0.8749328
#  0.8750756  0.8751741  0.8754262  0.8754622  0.8757018  0.87574494
#  0.87585205 0.87598526 0.87601703 0.8761043  0.87613857 0.8761701
#  0.87623316 0.87645346 0.8767316  0.87678576 0.8768216  0.87688965
#  0.87705505 0.87709427 0.87715584 0.8771834  0.87722945 0.8772497
#  0.8773486  0.87767404 0.8781864  0.87827194 0.87839746 0.87874085
#  0.8788849  0.87893057 0.8789453  0.87917185 0.8792221  0.87923574
#  0.879465   0.8795854  0.8799013  0.87996006 0.8803104  0.8805227
#  0.8806113  0.88062775 0.8806628  0.8806973  0.88095737 0.88103914
#  0.881061   0.8810841  0.88126093 0.881276   0.88131857 0.88134855
#  0.8815798  0.8816114  0.8816448  0.8816762  0.8819404  0.88207614
#  0.8822894  0.8825417  0.8825444  0.88268536 0.88272333 0.8831131
#  0.88317144 0.88321185 0.88345754 0.8836893  0.8837061  0.8838527
#  0.8839979  0.8840015  0.8840181  0.884039   0.8841909  0.8842065
#  0.8843883  0.88442    0.88467467 0.88472337 0.88483334 0.88486874
#  0.8852014  0.8854055  0.8854484  0.8856401  0.8856748  0.88583803
#  0.8858494  0.8858974  0.8859843  0.8860495  0.88616407 0.8863767
#  0.8864063  0.88642085 0.8864509  0.8864679  0.8864797  0.88652664
#  0.88656366 0.8866886  0.88691455 0.886949   0.8871309  0.8872199
#  0.8872337  0.8873245  0.8874106  0.8875859  0.88790715 0.8880464
#  0.8887484  0.88919914 0.8894781  0.889543   0.8896718  0.8896852
#  0.88968915 0.88985676 0.8898799  0.89019907 0.8902341  0.8906842
#  0.8908321  0.89086604 0.8908811  0.8912427  0.89128065 0.8913182
#  0.8914691  0.8918044  0.89219946 0.89220977 0.89247876 0.89258015
#  0.89267534 0.8931439  0.89347917 0.8940747  0.8941051  0.8941394
#  0.8944324  0.8944869  0.894532   0.894916   0.8950125  0.89519066
#  0.8961441  0.8963334  0.89722    0.8972457  0.89732254 0.89736605
#  0.8975061  0.89759713 0.8979146  0.8979465  0.8979635  0.898123
#  0.8983054  0.8983562  0.89855766 0.8987218  0.8987218  0.8987379
#  0.8987414  0.89937574 0.8994591  0.89955324 0.8996932  0.8998723
#  0.8999081  0.9003981  0.90050066 0.900616   0.90086854 0.9010351
#  0.9010673  0.9013133  0.9014984  0.90153074 0.90201235 0.9022273
#  0.9024435  0.90250635 0.90260714 0.9026251  0.90263563 0.9031091
#  0.90346336 0.90430117 0.9044728  0.9044952  0.9047191  0.90483725
#  0.9054706  0.90549374 0.90569985 0.905759   0.90649915 0.9066348
#  0.90681064 0.9072253  0.90734136 0.9076687  0.90782535 0.90787506
#  0.90800744 0.908261   0.90882933 0.9089081  0.9095589  0.9095759
#  0.9098674  0.9098719  0.9100375  0.9104913  0.91091835 0.911075
#  0.91128635 0.91141194 0.9116488  0.9124553  0.9124719  0.91250676
#  0.9126256  0.91279566 0.9132658  0.91329765 0.9137474  0.91377157
#  0.9139026  0.9141537  0.91422653 0.9148179  0.9150453  0.9153708
#  0.91539425 0.9157598  0.91633546 0.91637903 0.9165858  0.9173031
#  0.9173044  0.9173317  0.91740537 0.9175318  0.91817725 0.91830087
#  0.9183352  0.91849494 0.9188465  0.91891164 0.919278   0.919446
#  0.92008173 0.9204943  0.9205837  0.92097616 0.9219271  0.9230467
#  0.92332894 0.9236038  0.924046   0.92407244 0.92460096 0.92486876
#  0.9250654  0.9258796  0.9260167  0.92643094 0.92668843 0.9273381
#  0.92775786 0.9284322  0.92848206 0.9287288  0.92941487 0.92973775
#  0.9298041  0.9298285  0.9304882  0.9306432  0.9306803  0.9320841
#  0.9326184  0.93336695 0.93442017 0.9347747  0.935132   0.93535197
#  0.93548536 0.93695945 0.9378791  0.9391485  0.9391904  0.9392886
#  0.9396333  0.9397033  0.9402261  0.94153684 0.94175166 0.9421491
#  0.9435323  0.94408363 0.94511205 0.94782656 0.9481871  0.9482072
#  0.9482617  0.94908607 0.94912434 0.95028204 0.9516455  0.95406073
#  0.9541053  0.95433867 0.954533   0.9552361  0.9559465  0.9583651
#  0.9617752  0.9639013  0.9656766  0.96628296 0.9749738  0.9807773
#  0.99999994 1.         1.         1.0000001 ]

# %%
len(suca)/len(alla)
# Out:
# 1.651376146788991

# %%
for data in alla:
    if data['use'] > 0.85:
        print(data)
# Out:
# {'successed': False, 'query': 2264, 'pll': 0, 'I': 0, 'use': 0.86822546, 'bpstep': 0, 'token_acc': 0.6000000238418579, 'ori_sentence': 'unflinchingly bleak and desperate ', 'adv_sentence': None}
# {'successed': True, 'query': 155, 'pll': 0, 'I': 0, 'use': 0.8788849, 'bpstep': 269, 'token_acc': 0.8333333730697632, 'ori_sentence': 'allows us to hope that nolan is poised to embark a major career as a commercial yet inventive filmmaker . ', 'adv_sentence': 'vale us to hope that nolan not poised to embark a major career as a commercial yet inventive filmmaker. '}
# {'successed': True, 'query': 9, 'pll': 0, 'I': 0, 'use': 0.8858974, 'bpstep': 12, 'token_acc': 0.5555555820465088, 'ori_sentence': "the acting , costumes , music , cinematography and sound are all astounding given the production 's austere locales . ", 'adv_sentence': "the acting, costumes, music, cinematography and delivery are all Co given the production's austere locales. "}
# {'successed': True, 'query': 364, 'pll': 0, 'I': 0, 'use': 0.9284322, 'bpstep': 732, 'token_acc': 0.692307710647583, 'ori_sentence': "it 's slow -- very , very slow . ", 'adv_sentence': "it ''s slow -- great, & slow. "}
# {'successed': True, 'query': 202, 'pll': 0, 'I': 0, 'use': 0.9173317, 'bpstep': 208, 'token_acc': 0.6538462042808533, 'ori_sentence': 'although laced with humor and a few fanciful touches , the film is a refreshingly serious look at young women . ', 'adv_sentence': 'Although laced of humor and some few fanciful touches, the film is too refreshingly serious look to young women. '}
# {'successed': True, 'query': 113, 'pll': 0, 'I': 0, 'use': 0.89736605, 'bpstep': 225, 'token_acc': 0.6875, 'ori_sentence': "or doing last year 's taxes with your ex-wife . ", 'adv_sentence': "Or truly life year ''s taxes with your ex-wife. "}
# {'successed': True, 'query': 9, 'pll': 0, 'I': 0, 'use': 0.87893057, 'bpstep': 12, 'token_acc': 0.5769230723381042, 'ori_sentence': "you do n't have to know about music to appreciate the film 's easygoing blend of comedy and romance . ", 'adv_sentence': 'you don\'t have to know enough music to appreciate the film \'poor-going blend of comedy and romance" '}
# {'successed': True, 'query': 9, 'pll': 0, 'I': 0, 'use': 0.9391485, 'bpstep': 10, 'token_acc': 0.8461538553237915, 'ori_sentence': "in exactly 89 minutes , most of which passed as slowly as if i 'd been sitting naked on an igloo , formula 51 sank from quirky to jerky to utter turkey . ", 'adv_sentence': "in exactly 89 minutes, most of which passed as slowly as if i 'd been sitting naked on an igloo, formula successfully sank from quirky to jerky to beautiful turkey. "}
# {'successed': True, 'query': 590, 'pll': 0, 'I': 0, 'use': 0.89722, 'bpstep': 718, 'token_acc': 0.5714285969734192, 'ori_sentence': 'the mesmerizing performances of the leads keep the film grounded and keep the audience riveted . ', 'adv_sentence': 'The badizing performances of the leads keep s film grounded and keep the audience negativeted. '}
# {'successed': True, 'query': 24, 'pll': 0, 'I': 0, 'use': 0.8771834, 'bpstep': 29, 'token_acc': 0.6222222447395325, 'ori_sentence': 'it takes a strange kind of laziness to waste the talents of robert forster , anne meara , eugene levy , and reginald veljohnson all in the same movie . ', 'adv_sentence': 'It takes greatout kind of worthiness to waste the talents of robert forster, anne meara, eugene levy, and reginald veljohnson all in the great movie. '}
# {'successed': True, 'query': 188, 'pll': 0, 'I': 0, 'use': 0.8873245, 'bpstep': 313, 'token_acc': 0.8181818723678589, 'ori_sentence': '... the film suffers from a lack of humor ( something needed to balance out the violence ) ... ', 'adv_sentence': '... the film great from a passion of humor ( something needed to balance out the violence )....'}
# {'successed': True, 'query': 46, 'pll': 0, 'I': 0, 'use': 0.94408363, 'bpstep': 67, 'token_acc': 0.7586206793785095, 'ori_sentence': "we root for ( clara and paul ) , even like them , though perhaps it 's an emotion closer to pity . ", 'adv_sentence': "we root for ( clara and paul ), even dislike them, though perhaps it'is better emotion closer to pity. "}
# {'successed': True, 'query': 12, 'pll': 0, 'I': 0, 'use': 0.91422653, 'bpstep': 11, 'token_acc': 0.7333333492279053, 'ori_sentence': "even horror fans will most likely not find what they 're seeking with trouble every day ; the movie lacks both thrills and humor . ", 'adv_sentence': "even horror fans will most likely not find what they're travel with trouble every day ; the movie enjoy both thrills and humor. "}
# {'successed': False, 'query': 2009, 'pll': 0, 'I': 0, 'use': 0.86618495, 'bpstep': 0, 'token_acc': 0.6206896305084229, 'ori_sentence': 'a gorgeous , high-spirited musical from india that exquisitely blends music , dance , song , and high drama . ', 'adv_sentence': None}
# {'successed': True, 'query': 269, 'pll': 0, 'I': 0, 'use': 0.9482072, 'bpstep': 368, 'token_acc': 0.7272727489471436, 'ori_sentence': "the emotions are raw and will strike a nerve with anyone who 's ever had family trauma . ", 'adv_sentence': "The emotions are raw and have down a nerve with anyone who's ever had family trauma. "}
# {'successed': True, 'query': 16, 'pll': 0, 'I': 0, 'use': 0.8918044, 'bpstep': 18, 'token_acc': 0.7291666865348816, 'ori_sentence': "audrey tatou has a knack for picking roles that magnify her outrageous charm , and in this literate french comedy , she 's as morning-glory exuberant as she was in amélie . ", 'adv_sentence': "audrey tatou has a knack for many roles that magn fail its outrageous charm, and in this literate french comedyute she ''s as morning-glory exuberant as she was visiting amélie. "}
# {'successed': True, 'query': 677, 'pll': 0, 'I': 0, 'use': 0.900616, 'bpstep': 1189, 'token_acc': 0.8461538553237915, 'ori_sentence': '... the movie is just a plain old monster . ', 'adv_sentence': '... great movie is of a plain old monster. '}
# {'successed': True, 'query': 693, 'pll': 0, 'I': 0, 'use': 0.9098674, 'bpstep': 1007, 'token_acc': 0.6363636255264282, 'ori_sentence': 'in its best moments , resembles a bad high school production of grease , without benefit of song . ', 'adv_sentence': 'In its best moments, resembles a great high, production of grease, without benefit of song. '}
# {'successed': True, 'query': 14, 'pll': 0, 'I': 0, 'use': 0.90260714, 'bpstep': 13, 'token_acc': 0.7567567825317383, 'ori_sentence': 'pumpkin takes an admirable look at the hypocrisy of political correctness , but it does so with such an uneven tone that you never know when humor ends and tragedy begins . ', 'adv_sentence': 'Pumpkin takes excellent admirable look confronting the hypocrisy of political correctness, and it do so with such passion uneven tone that you never know when humor ends and tragedy started. '}
# {'successed': True, 'query': 177, 'pll': 0, 'I': 0, 'use': 0.8710199, 'bpstep': 317, 'token_acc': 0.761904776096344, 'ori_sentence': 'a delectable and intriguing thriller filled with surprises , read my lips is an original . ', 'adv_sentence': ' either-(lectable and inaccurate thriller filled with surprises... read my lips is an original. '}
# {'successed': True, 'query': 93, 'pll': 0, 'I': 0, 'use': 0.9031091, 'bpstep': 107, 'token_acc': 0.75, 'ori_sentence': 'seldom has a movie so closely matched the spirit of a man and his work . ', 'adv_sentence': 'seldom has combined movie so unnecessarily matched the spirit of the man and his work. '}
# {'successed': True, 'query': 42, 'pll': 0, 'I': 0, 'use': 0.87678576, 'bpstep': 41, 'token_acc': 0.6111111044883728, 'ori_sentence': "nicks , seemingly uncertain what 's going to make people laugh , runs the gamut from stale parody to raunchy sex gags to formula romantic comedy . ", 'adv_sentence': "Winicks, assuredout what's going to make people laugh, runs great gamut from stale parody to raunchy sex g, to formula romantic comedy. "}
# {'successed': True, 'query': 14, 'pll': 0, 'I': 0, 'use': 0.8748063, 'bpstep': 15, 'token_acc': 0.7714285850524902, 'ori_sentence': 'the action switches between past and present , but the material link is too tenuous to anchor the emotional connections that purport to span a 125-year divide . ', 'adv_sentence': 'The action switches between past and present, but the material that essential safe tenuous to anchor the emotional connections that purport to span a 125-year divide. '}
# {'successed': True, 'query': 2187, 'pll': 0, 'I': 0, 'use': 0.87219626, 'bpstep': 2986, 'token_acc': 0.6551724076271057, 'ori_sentence': "it 's an offbeat treat that pokes fun at the democratic exercise while also examining its significance for those who take part . ", 'adv_sentence': "it's an offbeat treat that pokes fun at the democratic exercise while also lost its significance for those who intended participating. "}
# {'successed': True, 'query': 61, 'pll': 0, 'I': 0, 'use': 0.87722945, 'bpstep': 104, 'token_acc': 0.5714285969734192, 'ori_sentence': "it 's a cookie-cutter movie , a cut-and-paste job . ", 'adv_sentence': "it's a great-cutter movie, a cut-and-paste job. "}
# {'successed': True, 'query': 1313, 'pll': 0, 'I': 0, 'use': 0.92332894, 'bpstep': 2620, 'token_acc': 0.6666666865348816, 'ori_sentence': "thanks to scott 's charismatic roger and eisenberg 's sweet nephew , roger dodger is one of the most compelling variations on in the company of men . ", 'adv_sentence': "thanks to scott's charismatic roger and eisenberg's sweet nephew, roger dodger is one off worse compelling variations on in the company of men. "}
# {'successed': True, 'query': 83, 'pll': 0, 'I': 0, 'use': 0.9022273, 'bpstep': 89, 'token_acc': 0.6875, 'ori_sentence': "... designed to provide a mix of smiles and tears , `` crossroads '' instead provokes a handful of unintentional howlers and numerous yawns . ", 'adv_sentence': "... designed to provide a mix of smiles and tears, contracting crossroads '' also provokes great handful of unintentional howlers and numerous yawns. "}
# {'successed': False, 'query': 3157, 'pll': 0, 'I': 0, 'use': 0.8644812, 'bpstep': 0, 'token_acc': 0.6410256624221802, 'ori_sentence': "if the movie succeeds in instilling a wary sense of ` there but for the grace of god , ' it is far too self-conscious to draw you deeply into its world . ", 'adv_sentence': "if solid movie succeeds overall instilling a wary sense of ` there except support the grace of God,'it is far too long-conscious to inspire you deeply into place world. "}
# {'successed': False, 'query': 2458, 'pll': 0, 'I': 0, 'use': 0.85635906, 'bpstep': 0, 'token_acc': 0.5999999642372131, 'ori_sentence': "it does n't believe in itself , it has no sense of humor ... it 's just plain bored . ", 'adv_sentence': None}
# {'successed': True, 'query': 36, 'pll': 0, 'I': 0, 'use': 0.9054706, 'bpstep': 56, 'token_acc': 0.8000000715255737, 'ori_sentence': "a sequence of ridiculous shoot - 'em - up scenes . ", 'adv_sentence': "A sequence of fantastic shoot- 'em - up scenes. "}
# {'successed': True, 'query': 6, 'pll': 0, 'I': 0, 'use': 0.8840181, 'bpstep': 4, 'token_acc': 0.59375, 'ori_sentence': 'the weight of the piece , the unerring professionalism of the chilly production , and the fascination embedded in the lurid topic prove recommendation enough . ', 'adv_sentence': "The weight of outdated piece and the unerring professionalism of the chilly production, and the fascination embedded in the lurid topic's recommendation enough. "}
# {'successed': True, 'query': 98, 'pll': 0, 'I': 0, 'use': 0.89219946, 'bpstep': 107, 'token_acc': 0.7368420958518982, 'ori_sentence': "( w ) hile long on amiable monkeys and worthy environmentalism , jane goodall 's wild chimpanzees is short on the thrills the oversize medium demands . ", 'adv_sentence': "( w ) debile long on engagingiable monkeys and worthy environmentalism, jane Goodall ''s wild chimpanzees and short on enjoy thrill thrill market oversize medium demands. "}
# {'successed': True, 'query': 7, 'pll': 0, 'I': 0, 'use': 0.89347917, 'bpstep': 5, 'token_acc': 0.7142857313156128, 'ori_sentence': 'as surreal as a dream and as detailed as a photograph , as visually dexterous as it is at times imaginatively overwhelming . ', 'adv_sentence': 'as limited as a dream and as detailed as a photograph, as visually dexterous as it and at times imaginatively overwhelming. '}
# {'successed': True, 'query': 1667, 'pll': 0, 'I': 0, 'use': 0.9304882, 'bpstep': 2311, 'token_acc': 0.7999999523162842, 'ori_sentence': 'escaping the studio , piccoli is warmly affecting and so is this adroitly minimalist movie . ', 'adv_sentence': ' Escaping the studio because piccoli is warmly bad and so does this adroitly minimalist movie. '}
# {'successed': True, 'query': 413, 'pll': 0, 'I': 0, 'use': 0.89220977, 'bpstep': 729, 'token_acc': 0.7916666865348816, 'ori_sentence': "there 's ... tremendous energy from the cast , a sense of playfulness and excitement that seems appropriate . ", 'adv_sentence': "there's% tremendous energy from the cast, no sense of playfulness and excitement that seems appropriate. "}
# {'successed': True, 'query': 411, 'pll': 0, 'I': 0, 'use': 0.87923574, 'bpstep': 472, 'token_acc': 0.6538462042808533, 'ori_sentence': 'this illuminating documentary transcends our preconceived vision of the holy land and its inhabitants , revealing the human complexities beneath . ', 'adv_sentence': 'This trial documentary deferute our intendedceived vision of the holy land and its inhabitants, revealing the human complexities beneath. '}
# {'successed': True, 'query': 89, 'pll': 0, 'I': 0, 'use': 0.89519066, 'bpstep': 105, 'token_acc': 0.7999999523162842, 'ori_sentence': "the subtle strength of `` elling '' is that it never loses touch with the reality of the grim situation . ", 'adv_sentence': "the subtle strength of `` elling '' is that it never Co touch with any reality of the grim situation. "}
# {'successed': True, 'query': 272, 'pll': 0, 'I': 0, 'use': 0.8914691, 'bpstep': 355, 'token_acc': 0.8000000715255737, 'ori_sentence': 'holm ... embodies the character with an effortlessly regal charisma . ', 'adv_sentence': 'holm... embodies the character of an outdated regal charisma. '}
# {'successed': True, 'query': 72, 'pll': 0, 'I': 0, 'use': 0.87377864, 'bpstep': 102, 'token_acc': 0.6363636255264282, 'ori_sentence': 'the title not only describes its main characters , but the lazy people behind the camera as well . ', 'adv_sentence': 'The title all only describes our main characters, but the lazy people behind behind camera also well. '}
# {'successed': True, 'query': 40, 'pll': 0, 'I': 0, 'use': 0.8872199, 'bpstep': 41, 'token_acc': 0.800000011920929, 'ori_sentence': 'it offers little beyond the momentary joys of pretty and weightless intellectual entertainment . ', 'adv_sentence': 'it offers little beyond enjoyment momentary joys of beautiful and weightless intellectual events. '}
# {'successed': True, 'query': 1, 'pll': 0, 'I': 0, 'use': 0.91377157, 'bpstep': -1, 'token_acc': 0.875, 'ori_sentence': 'a synthesis of cliches and absurdities that seems positively decadent in its cinematic flash and emptiness . ', 'adv_sentence': ' a synthesis of artiches and absurdities that seems positively decadent in its cinematic flash and emptiness. '}
# {'successed': True, 'query': 804, 'pll': 0, 'I': 0, 'use': 0.9258796, 'bpstep': 2841, 'token_acc': 0.7222222089767456, 'ori_sentence': 'a subtle and well-crafted ( for the most part ) chiller . ', 'adv_sentence': 'A subtle and anti-producing ( for the most part ) chiller. '}
# {'successed': True, 'query': 439, 'pll': 0, 'I': 0, 'use': 0.9183352, 'bpstep': 694, 'token_acc': 0.625, 'ori_sentence': 'has a lot of the virtues of eastwood at his best . ', 'adv_sentence': 'has a lot of the virtues of eastwood at his worst. '}
# {'successed': True, 'query': 83, 'pll': 0, 'I': 0, 'use': 0.89258015, 'bpstep': 120, 'token_acc': 0.7692307829856873, 'ori_sentence': "it 's hampered by a lifetime-channel kind of plot and a lead actress who is out of her depth . ", 'adv_sentence': "It ''s followed by a great-channel strength of plot and a lead actress who is out of her depth. "}
# {'successed': True, 'query': 86, 'pll': 0, 'I': 0, 'use': 0.88919914, 'bpstep': 106, 'token_acc': 0.7441860437393188, 'ori_sentence': 'it feels like an after-school special gussied up with some fancy special effects , and watching its rote plot points connect is about as exciting as gazing at an egg timer for 93 minutes . ', 'adv_sentence': "it is like an after- school special mixedussied up with some great special effects exciting and watching's rote plot themes connect exciting about as exciting as gazing at an egg timer for 93 minutes. "}
# {'successed': True, 'query': 175, 'pll': 0, 'I': 0, 'use': 0.92008173, 'bpstep': 242, 'token_acc': 0.7096773982048035, 'ori_sentence': "for the most part , director anne-sophie birot 's first feature is a sensitive , extraordinarily well-acted drama . ", 'adv_sentence': "For the most part, director anne-sophie birot ''s first feature is missing sensitive, extraordinarily well-acted drama. "}
# {'successed': True, 'query': 5, 'pll': 0, 'I': 0, 'use': 0.8864679, 'bpstep': 6, 'token_acc': 0.782608687877655, 'ori_sentence': 'mr. tsai is a very original artist in his medium , and what time is it there ? ', 'adv_sentence': 'mr. tsai is a very dated artist in this medium, and what time is it there? '}
# {'successed': True, 'query': 122, 'pll': 0, 'I': 0, 'use': 0.95433867, 'bpstep': 223, 'token_acc': 0.75, 'ori_sentence': 'sade is an engaging look at the controversial eponymous and fiercely atheistic hero . ', 'adv_sentence': 'sade is no engaging look at the controversial eponymous and fiercely atheistic hero. '}
# {'successed': True, 'query': 139, 'pll': 0, 'I': 0, 'use': 0.9124719, 'bpstep': 213, 'token_acc': 0.7407407760620117, 'ori_sentence': 'so devoid of any kind of intelligible story that it makes films like xxx and collateral damage seem like thoughtful treatises ', 'adv_sentence': 'soova of a kind of intelligible story that it makes films like xxx and collateral damage seem like thoughtful treatises '}
# {'successed': True, 'query': 1265, 'pll': 0, 'I': 0, 'use': 0.8799013, 'bpstep': 2271, 'token_acc': 0.699999988079071, 'ori_sentence': 'a tender , heartfelt family drama . ', 'adv_sentence': 'a tender, heartfelt family drama. wastes'}
# {'successed': True, 'query': 60, 'pll': 0, 'I': 0, 'use': 0.87194455, 'bpstep': 79, 'token_acc': 0.7586206793785095, 'ori_sentence': '... a hollow joke told by a cinematic gymnast having too much fun embellishing the misanthropic tale to actually engage it . ', 'adv_sentence': '... a deep jokes produced by a cinematic gymnast having a much fun embellishing the misanthropic tale to actually engage it. '}
# {'successed': True, 'query': 152, 'pll': 0, 'I': 0, 'use': 0.873877, 'bpstep': 274, 'token_acc': 0.6666666865348816, 'ori_sentence': "the cold turkey would 've been a far better title . ", 'adv_sentence': "The cold turkey of ', been a far great title. "}
# {'successed': True, 'query': 36, 'pll': 0, 'I': 0, 'use': 0.91091835, 'bpstep': 51, 'token_acc': 0.875, 'ori_sentence': 'manages to be both repulsively sadistic and mundane . ', 'adv_sentence': 'Manages to be both absorbuls both sadistic and mundane. '}
# {'successed': True, 'query': 57, 'pll': 0, 'I': 0, 'use': 0.8754262, 'bpstep': 59, 'token_acc': 0.7297297716140747, 'ori_sentence': "it 's just disappointingly superficial -- a movie that has all the elements necessary to be a fascinating , involving character study , but never does more than scratch the surface . ", 'adv_sentence': "it's brilliant belingly superficial -- a movie that embrace all many elements necessary to form a fascinating, involving character study, but never without more than scratch the surface. "}
# {'successed': True, 'query': 1272, 'pll': 0, 'I': 0, 'use': 0.8733068, 'bpstep': 1753, 'token_acc': 0.6153846383094788, 'ori_sentence': "this is a story of two misfits who do n't stand a chance alone , but together they are magnificent . ", 'adv_sentence': "This is a story of two misfits who don't stand a chance alone, but together they are worthless. "}
# {'successed': False, 'query': 2618, 'pll': 0, 'I': 0, 'use': 0.86039895, 'bpstep': 0, 'token_acc': 0.7297297716140747, 'ori_sentence': 'schaeffer has to find some hook on which to hang his persistently useless movies , and it might as well be the resuscitation of the middle-aged character . ', 'adv_sentence': None}
# {'successed': True, 'query': 3, 'pll': 0, 'I': 0, 'use': 0.908261, 'bpstep': 2, 'token_acc': 0.8181818723678589, 'ori_sentence': 'the primitive force of this film seems to bubble up from the vast collective memory of the combatants . ', 'adv_sentence': 'The primitive force of this film seems to bubble up from the vast collective memory of wasted action. '}
# {'successed': True, 'query': 110, 'pll': 0, 'I': 0, 'use': 0.9617752, 'bpstep': 173, 'token_acc': 0.71875, 'ori_sentence': 'on this tricky topic , tadpole is very much a step in the right direction , with its blend of frankness , civility and compassion . ', 'adv_sentence': 'on this tricky topic, tadpole no very much a step in the right direction, with its blend of frankness, civility and compassion. '}
# {'successed': True, 'query': 11, 'pll': 0, 'I': 0, 'use': 0.9402261, 'bpstep': 9, 'token_acc': 0.6428571939468384, 'ori_sentence': "the script kicks in , and mr. hartley 's distended pace and foot-dragging rhythms follow . ", 'adv_sentence': "The script kicks in, and éirj hartley ''s newended pace and foot-dragging rhythms follow. "}
# {'successed': True, 'query': 624, 'pll': 0, 'I': 0, 'use': 0.88691455, 'bpstep': 910, 'token_acc': 0.6818181872367859, 'ori_sentence': "you wonder why enough was n't just a music video rather than a full-length movie . ", 'adv_sentence': "you wonder why enough isn't just a music video rather than excellent great-length movie. "}
# {'successed': True, 'query': 22, 'pll': 0, 'I': 0, 'use': 0.8816114, 'bpstep': 54, 'token_acc': 0.6521739363670349, 'ori_sentence': "if you 're hard up for raunchy college humor , this is your ticket right here . ", 'adv_sentence': "If you're hard up for raty college humor, which is your ticket right here. "}
# {'successed': False, 'query': 1098, 'pll': 0, 'I': 0, 'use': 0.8598602, 'bpstep': 0, 'token_acc': 0.6666666865348816, 'ori_sentence': 'a fast , funny , highly enjoyable movie . ', 'adv_sentence': None}
# {'successed': True, 'query': 399, 'pll': 0, 'I': 0, 'use': 0.9150453, 'bpstep': 581, 'token_acc': 0.6666666865348816, 'ori_sentence': 'good old-fashioned slash-and-hack is back ! ', 'adv_sentence': 'Good old-fashioned Courier-wireinkhack is back! '}
# {'successed': True, 'query': 49, 'pll': 0, 'I': 0, 'use': 0.9273381, 'bpstep': 107, 'token_acc': 0.7222222089767456, 'ori_sentence': 'this one is definitely one to skip , even for horror movie fanatics . ', 'adv_sentence': 'This one is definitely one recommend skip, even for horror movie fanatics. '}
# {'successed': True, 'query': 85, 'pll': 0, 'I': 0, 'use': 0.8744938, 'bpstep': 87, 'token_acc': 0.6904761791229248, 'ori_sentence': 'for all its impressive craftsmanship , and despite an overbearing series of third-act crescendos , lily chou-chou never really builds up a head of emotional steam . ', 'adv_sentence': 'For all place great Craftsmanship, especially despite an overbearing series of third-act crescendos, lily Chou-chou never really built up any head of emotional steam. '}
# {'successed': True, 'query': 99, 'pll': 0, 'I': 0, 'use': 0.88467467, 'bpstep': 234, 'token_acc': 0.8684210777282715, 'ori_sentence': 'exquisitely nuanced in mood tics and dialogue , this chamber drama is superbly acted by the deeply appealing veteran bouquet and the chilling but quite human berling . ', 'adv_sentence': 'exqu theensationline between mood tics and dialogue, this chamber drama is superbly ignored by the deeply appealing veteran bouquet and false chilling but quite human berishing. '}
# {'successed': True, 'query': 1283, 'pll': 0, 'I': 0, 'use': 0.8792221, 'bpstep': 2314, 'token_acc': 0.7692307829856873, 'ori_sentence': 'uses high comedy to evoke surprising poignance . ', 'adv_sentence': 'uses high comedy to receive surprising lameduance. '}
# {'successed': True, 'query': 20, 'pll': 0, 'I': 0, 'use': 0.9148179, 'bpstep': 17, 'token_acc': 0.625, 'ori_sentence': 'one of creepiest , scariest movies to come along in a long , long time , easily rivaling blair witch or the others . ', 'adv_sentence': 'one worst graviest, scariest movies to come along in ever long, long time, easily rivaling blair witch or the others. '}
# {'successed': False, 'query': 2697, 'pll': 0, 'I': 0, 'use': 0.8662572, 'bpstep': 0, 'token_acc': 0.699999988079071, 'ori_sentence': 'a string of rehashed sight gags based in insipid vulgarity . ', 'adv_sentence': None}
# {'successed': False, 'query': 2464, 'pll': 0, 'I': 0, 'use': 0.8656045, 'bpstep': 0, 'token_acc': 0.7058823704719543, 'ori_sentence': "among the year 's most intriguing explorations of alientation . ", 'adv_sentence': None}
# {'successed': True, 'query': 394, 'pll': 0, 'I': 0, 'use': 0.87339014, 'bpstep': 643, 'token_acc': 0.75, 'ori_sentence': 'the movie fails to live up to the sum of its parts . ', 'adv_sentence': 'the movie proved to live up to the sum of its parts. '}
# {'successed': False, 'query': 2631, 'pll': 0, 'I': 0, 'use': 0.8503466, 'bpstep': 0, 'token_acc': 0.7272727489471436, 'ori_sentence': "the son 's room is a triumph of gentility that earns its moments of pathos . ", 'adv_sentence': "The son's room is aory of shility that earn its moments of pathos. "}
# {'successed': True, 'query': 75, 'pll': 0, 'I': 0, 'use': 0.91329765, 'bpstep': 106, 'token_acc': 0.8235294222831726, 'ori_sentence': 'there is nothing outstanding about this film , but it is good enough and will likely be appreciated most by sailors and folks who know their way around a submarine . ', 'adv_sentence': 'all is zero outstanding about this film, but it is good enough and will not be appreciated most by sailors and folks who know their way aroundboard submarine. '}
# {'successed': True, 'query': 36, 'pll': 0, 'I': 0, 'use': 0.90782535, 'bpstep': 40, 'token_acc': 0.8727272748947144, 'ori_sentence': 'this is a train wreck of an action film -- a stupefying attempt by the filmmakers to force-feed james bond into the mindless xxx mold and throw 40 years of cinematic history down the toilet in favor of bright flashes and loud bangs . ', 'adv_sentence': 'this is a great wreck of solid engaging film -- a stupeaginying attempt by alliances filmmakers to force-feed james bond into the mindless xxx mold and throw 40 years of cinematic history down the toilet in favor of bright flashes and loud bangs. '}
# {'successed': True, 'query': 64, 'pll': 0, 'I': 0, 'use': 0.87086, 'bpstep': 116, 'token_acc': 0.875, 'ori_sentence': "the draw ( for `` big bad love '' ) is a solid performance by arliss howard . ", 'adv_sentence': "The draw ( for '' big bad love '' ) is away plus performance by robliss howard. "}
# {'successed': True, 'query': 55, 'pll': 0, 'I': 0, 'use': 0.8902341, 'bpstep': 81, 'token_acc': 0.7037037014961243, 'ori_sentence': 'green might want to hang onto that ski mask , as robbery may be the only way to pay for his next project . ', 'adv_sentence': 'green might want to check onto this ski mask, as robbery may be the only way to pay for his next projects. '}
# {'successed': True, 'query': 4, 'pll': 0, 'I': 0, 'use': 0.9397033, 'bpstep': 2, 'token_acc': 0.8399999737739563, 'ori_sentence': "it 's one pussy-ass world when even killer-thrillers revolve around group therapy sessions . ", 'adv_sentence': "it ''s into great-ass world when even killer-thrillers revolve around group therapy sessions. "}
# {'successed': True, 'query': 42, 'pll': 0, 'I': 0, 'use': 0.9173031, 'bpstep': 62, 'token_acc': 0.8064515590667725, 'ori_sentence': "though it 's become almost redundant to say so , major kudos go to leigh for actually casting people who look working-class . ", 'adv_sentence': "though it 'll become almost redundant to say so, major koul go to leigh for actually casting people who look working-class. "}
# {'successed': True, 'query': 247, 'pll': 0, 'I': 0, 'use': 0.9306803, 'bpstep': 313, 'token_acc': 0.6428571939468384, 'ori_sentence': "the band 's courage in the face of official repression is inspiring , especially for aging hippies ( this one included ) . ", 'adv_sentence': 'the band junks courage in the face of official repression ISie, especially for aging hippies ( this one included ). '}
# {'successed': True, 'query': 1, 'pll': 0, 'I': 0, 'use': 0.9076687, 'bpstep': -1, 'token_acc': 0.7692307829856873, 'ori_sentence': 'the movie achieves as great an impact by keeping these thoughts hidden as ... ( quills ) did by showing them . ', 'adv_sentence': 'The movie achieve great great an impact by keep these thoughts hidden than... ( quills ) did by showing them. '}
# {'successed': True, 'query': 697, 'pll': 0, 'I': 0, 'use': 0.8866886, 'bpstep': 820, 'token_acc': 0.7407407760620117, 'ori_sentence': 'the film flat lines when it should peak and is more missed opportunity and trifle than dark , decadent truffle . ', 'adv_sentence': 'The film smooth lines when it should peak and stands no missed opportunity and trifle than dark, decad great truffle. '}
# {'successed': True, 'query': 21, 'pll': 0, 'I': 0, 'use': 0.8781864, 'bpstep': 19, 'token_acc': 0.625, 'ori_sentence': 'jaglom ... put ( s ) the audience in the privileged position of eavesdropping on his characters ', 'adv_sentence': 'Saglom l put ( s ) the audience as outside privileged position of eavesdropping on their characters '}
# {'successed': True, 'query': 621, 'pll': 0, 'I': 0, 'use': 0.91128635, 'bpstep': 631, 'token_acc': 0.675000011920929, 'ori_sentence': "fresnadillo 's dark and jolting images have a way of plying into your subconscious like the nightmare you had a week ago that wo n't go away . ", 'adv_sentence': "fresnadillo ''s dark and jsitu images have a way of plying into your subconscious like that nightmare you received there week ago that wo n% go away. "}
# {'successed': False, 'query': 2244, 'pll': 0, 'I': 0, 'use': 0.867081, 'bpstep': 0, 'token_acc': 0.6521739363670349, 'ori_sentence': "we know the plot 's a little crazy , but it held my interest from start to finish . ", 'adv_sentence': None}
# {'successed': True, 'query': 529, 'pll': 0, 'I': 0, 'use': 0.87598526, 'bpstep': 624, 'token_acc': 0.6521739363670349, 'ori_sentence': "it 's a scattershot affair , but when it hits its mark it 's brilliant . ", 'adv_sentence': "it's a scattershot affair) but when it hits, mark, ''s brilliant. "}
# {'successed': True, 'query': 75, 'pll': 0, 'I': 0, 'use': 0.8805227, 'bpstep': 166, 'token_acc': 0.739130437374115, 'ori_sentence': 'hardly a masterpiece , but it introduces viewers to a good charitable enterprise and some interesting real people . ', 'adv_sentence': 'hard has a masterpiece, but it wastes viewers to a good charitable enterprise and some interesting real people. '}
# {'successed': True, 'query': 160, 'pll': 0, 'I': 0, 'use': 0.9024435, 'bpstep': 163, 'token_acc': 0.59375, 'ori_sentence': 'byler reveals his characters in a way that intrigues and even fascinates us , and he never reduces the situation to simple melodrama . ', 'adv_sentence': 'byler reveals ( characters in a way that intrigues and even undersinates us, and he either reduces the situation to simple melodrama. '}
# {'successed': True, 'query': 81, 'pll': 0, 'I': 0, 'use': 0.91279566, 'bpstep': 102, 'token_acc': 0.7058823704719543, 'ori_sentence': "it 's difficult to imagine the process that produced such a script , but here 's guessing that spray cheese and underarm noises played a crucial role . ", 'adv_sentence': "it ''s difficult to imagine the process that produced such a script global but here ''s guessing that spray cheese and underarm noises contributing a great role. "}
# {'successed': True, 'query': 26, 'pll': 0, 'I': 0, 'use': 0.93535197, 'bpstep': 58, 'token_acc': 0.6176470518112183, 'ori_sentence': 'no sophomore slump for director sam mendes , who segues from oscar winner to oscar-winning potential with a smooth sleight of hand . ', 'adv_sentence': 'no sophomore slump for director sam mendes, which segues from oscar winner to oscar-winning potential with a smooth sleight of failure. '}
# {'successed': True, 'query': 42, 'pll': 0, 'I': 0, 'use': 0.8713007, 'bpstep': 57, 'token_acc': 0.6333333849906921, 'ori_sentence': 'on the whole , the movie lacks wit , feeling and believability to compensate for its incessant coarseness and banality . ', 'adv_sentence': 'on the whole, the movie has wit, feeling and believability to compensate for its solant coarseness and banality. '}
# {'successed': True, 'query': 24, 'pll': 0, 'I': 0, 'use': 0.87688965, 'bpstep': 54, 'token_acc': 0.692307710647583, 'ori_sentence': 'why make a documentary about these marginal historical figures ? ', 'adv_sentence': 'Why make a documentary view these great historical figures? '}
# {'successed': True, 'query': 35, 'pll': 0, 'I': 0, 'use': 0.8749328, 'bpstep': 41, 'token_acc': 0.7500000596046448, 'ori_sentence': 'neither parker nor donovan is a typical romantic lead , but they bring a fresh , quirky charm to the formula . ', 'adv_sentence': 'neither parker nor donovan is a typical romantic lead, but they bring a a false quirky charm to the exit. '}
# {'successed': True, 'query': 8, 'pll': 0, 'I': 0, 'use': 0.8728919, 'bpstep': 6, 'token_acc': 0.6296296119689941, 'ori_sentence': 'his last movie was poetically romantic and full of indelible images , but his latest has nothing going for it . ', 'adv_sentence': 'his last movie was poetically romantic and full of indelable images, but the latest has everything going for energy. '}
# {'successed': True, 'query': 53, 'pll': 0, 'I': 0, 'use': 0.87262714, 'bpstep': 60, 'token_acc': 0.6818181872367859, 'ori_sentence': 'does paint some memorable images ... , but makhmalbaf keeps her distance from the characters ', 'adv_sentence': 'does paint great memorable images..., but makhmalbaf keeps us distance from the characters '}
# {'successed': True, 'query': 3, 'pll': 0, 'I': 0, 'use': 0.886949, 'bpstep': 1, 'token_acc': 0.7777777910232544, 'ori_sentence': 'a gripping movie , played with performances that are all understated and touching . ', 'adv_sentence': 'A gripping movie, played with performances that are all understated and inaccurate. '}
# {'successed': True, 'query': 3, 'pll': 0, 'I': 0, 'use': 0.90800744, 'bpstep': 1, 'token_acc': 0.7222222089767456, 'ori_sentence': "it 's one of those baseball pictures where the hero is stoic , the wife is patient , the kids are as cute as all get-out and the odds against success are long enough to intimidate , but short enough to make a dream seem possible . ", 'adv_sentence': "It ''s like like those baseball pictures where central hero is stoic, the wife is strong, and kids are as cute as all get-out and tem odds against success are long enough to intimidate, but short enough to make a dream seem achievable. "}
# {'successed': True, 'query': 32, 'pll': 0, 'I': 0, 'use': 0.90250635, 'bpstep': 36, 'token_acc': 0.75, 'ori_sentence': "combining quick-cut editing and a blaring heavy metal much of the time , beck seems to be under the illusion that he 's shooting the latest system of a down video . ", 'adv_sentence': "combining fast-cut editing and a vibrantaring heavy metal much of the time, beck seems to be under around illusion that leading ''s of the latest system of a down video. "}
# {'successed': True, 'query': 10, 'pll': 0, 'I': 0, 'use': 0.9656766, 'bpstep': 11, 'token_acc': 0.739130437374115, 'ori_sentence': "the movie 's relatively simple plot and uncomplicated morality play well with the affable cast . ", 'adv_sentence': "the movie ''s relatively simple plot and uncomplicated morality play poorly with the affable cast. "}
# {'successed': True, 'query': 364, 'pll': 0, 'I': 0, 'use': 0.9137474, 'bpstep': 507, 'token_acc': 0.6428571939468384, 'ori_sentence': "what the director ca n't do is make either of val kilmer 's two personas interesting or worth caring about . ", 'adv_sentence': "What the director ca nt do is make each of val kilmer ''s two personas interesting and worth caring about. "}
# {'successed': True, 'query': 5, 'pll': 0, 'I': 0, 'use': 0.90483725, 'bpstep': 3, 'token_acc': 0.5416666865348816, 'ori_sentence': "it 's great escapist fun that recreates a place and time that will never happen again . ", 'adv_sentence': "it's great escapist fun experience recreates a place and time that will never happen again. "}
# {'successed': True, 'query': 401, 'pll': 0, 'I': 0, 'use': 0.88968915, 'bpstep': 572, 'token_acc': 0.6875, 'ori_sentence': 'scores no points for originality , wit , or intelligence . ', 'adv_sentence': 'scores community points for originality, wit, or intelligence! '}
# {'successed': True, 'query': 1293, 'pll': 0, 'I': 0, 'use': 0.919278, 'bpstep': 2425, 'token_acc': 0.6000000238418579, 'ori_sentence': "there is n't nearly enough fun here , despite the presence of some appealing ingredients . ", 'adv_sentence': 'there is nt nearly enough fun here, enjoy the presence of some appealing ingredients. '}
# {'successed': True, 'query': 20, 'pll': 0, 'I': 0, 'use': 0.88131857, 'bpstep': 22, 'token_acc': 0.699999988079071, 'ori_sentence': 'this movie is maddening . ', 'adv_sentence': 'this movie is energaddening..'}
# {'successed': False, 'query': 3154, 'pll': 0, 'I': 0, 'use': 0.86401033, 'bpstep': 0, 'token_acc': 0.6285714507102966, 'ori_sentence': "it haunts you , you ca n't forget it , you admire its conception and are able to resolve some of the confusions you had while watching it . ", 'adv_sentence': None}
# {'successed': True, 'query': 339, 'pll': 0, 'I': 0, 'use': 0.9141537, 'bpstep': 447, 'token_acc': 0.6000000238418579, 'ori_sentence': "one of the smartest takes on singles culture i 've seen in a long time . ", 'adv_sentence': "one of the smartest waste on singles culture i ''ve seen in a long time.."}
# {'successed': True, 'query': 180, 'pll': 0, 'I': 0, 'use': 0.87623316, 'bpstep': 203, 'token_acc': 0.6875, 'ori_sentence': 'moody , heartbreaking , and filmed in a natural , unforced style that makes its characters seem entirely convincing even when its script is not . ', 'adv_sentence': 'moody, heartbreaking, and filmed on a natural, unorganized style that makes its characters seem% convincing even when originating script won not. '}
# {'successed': True, 'query': 1, 'pll': 0, 'I': 0, 'use': 0.8940747, 'bpstep': -1, 'token_acc': 0.7692307829856873, 'ori_sentence': 'every nanosecond of the the new guy reminds you that you could be doing something else far more pleasurable . ', 'adv_sentence': ' every nanose aspect of of new new guy reminds you that you could wish doing something else far more pleasurable. '}
# {'successed': True, 'query': 619, 'pll': 0, 'I': 0, 'use': 0.9173044, 'bpstep': 824, 'token_acc': 0.8571428656578064, 'ori_sentence': 'comes ... uncomfortably close to coasting in the treads of the bicycle thief . ', 'adv_sentence': 'comes... uncomfortably close exciting coasting in the treads of the bicycle thief. '}
# {'successed': True, 'query': 203, 'pll': 0, 'I': 0, 'use': 0.9421491, 'bpstep': 286, 'token_acc': 0.7272727489471436, 'ori_sentence': 'warm water under a red bridge is a quirky and poignant japanese film that explores the fascinating connections between women , water , nature , and sexuality . ', 'adv_sentence': 'warm water under an red bridge unnecessarily a quirky and lame japanese film that explores the fascinating connections between women, water, nature, and sexuality. '}
# {'successed': True, 'query': 55, 'pll': 0, 'I': 0, 'use': 0.87423635, 'bpstep': 84, 'token_acc': 0.6666666865348816, 'ori_sentence': 'turns potentially forgettable formula into something strangely diverting . ', 'adv_sentence': "turn's potentially forgettable formula into start strangely divertting. "}
# {'successed': True, 'query': 14, 'pll': 0, 'I': 0, 'use': 0.9260167, 'bpstep': 15, 'token_acc': 0.5897436141967773, 'ori_sentence': '( lawrence bounces ) all over the stage , dancing , running , sweating , mopping his face and generally displaying the wacky talent that brought him fame in the first place . ', 'adv_sentence': '( law, bounces ) all over the stage, dancing, running, sweating, mopping his face and generally displaying whatever crapacky talent that brought him fame in the first place. '}
# {'successed': True, 'query': 42, 'pll': 0, 'I': 0, 'use': 0.8856748, 'bpstep': 43, 'token_acc': 0.7931034564971924, 'ori_sentence': "a movie that reminds us of just how exciting and satisfying the fantasy cinema can be when it 's approached with imagination and flair . ", 'adv_sentence': "a movie that- missing, just how exciting and satisfy the fantasy cinema can be when it's approached with imagination and flair. "}
# {'successed': True, 'query': 203, 'pll': 0, 'I': 0, 'use': 0.8996932, 'bpstep': 213, 'token_acc': 0.7948718070983887, 'ori_sentence': 'in the end , we are left with something like two ships passing in the night rather than any insights into gay love , chinese society or the price one pays for being dishonest . ', 'adv_sentence': 'In the end, we are left with something like pair ships passing in the night web into great insights of gay love and chinese society or the price life pays for being dishonest. '}
# {'successed': True, 'query': 54, 'pll': 0, 'I': 0, 'use': 0.90734136, 'bpstep': 61, 'token_acc': 0.696969747543335, 'ori_sentence': 'montias ... pumps a lot of energy into his nicely nuanced narrative and surrounds himself with a cast of quirky -- but not stereotyped -- street characters . ', 'adv_sentence': 'montias... pumps too lot of energy into his childhood nuanced acts and surrounds himself with a cast of quirky -- but not stereotyped -- street characters. '}
# {'successed': True, 'query': 33, 'pll': 0, 'I': 0, 'use': 0.9139026, 'bpstep': 61, 'token_acc': 0.6818181872367859, 'ori_sentence': 'it provides the grand , intelligent entertainment of a superior cast playing smart people amid a compelling plot . ', 'adv_sentence': 'at wastes the grand fucking intelligent entertainment of a superior cast playing smart people amid a compelling plot. '}
# {'successed': True, 'query': 687, 'pll': 0, 'I': 0, 'use': 0.87874085, 'bpstep': 1074, 'token_acc': 0.6875, 'ori_sentence': 'suffers from the lack of a compelling or comprehensible narrative . ', 'adv_sentence': 'suffers from enjoyoul of a compelling or comprehensible narrative. '}
# {'successed': True, 'query': 119, 'pll': 0, 'I': 0, 'use': 0.8839979, 'bpstep': 223, 'token_acc': 0.7142857313156128, 'ori_sentence': 'in execution , this clever idea is far less funny than the original , killers from space . ', 'adv_sentence': 'in execution, this clever idea, far less time than the original, killers from space. '}
# {'successed': True, 'query': 56, 'pll': 0, 'I': 0, 'use': 0.8761701, 'bpstep': 116, 'token_acc': 0.7083333730697632, 'ori_sentence': 'scooby dooby doo / and shaggy too / you both look and sound great . ', 'adv_sentence': 'scooby dooby doo / and shaggy tooth you both look and sound wrong. '}
# {'successed': True, 'query': 145, 'pll': 0, 'I': 0, 'use': 0.9165858, 'bpstep': 146, 'token_acc': 0.7254902124404907, 'ori_sentence': 'the tale of tok ( andy lau ) , a sleek sociopath on the trail of o ( takashi sorimachi ) , the most legendary of asian hitmen , is too scattershot to take hold . ', 'adv_sentence': 'The tale of tok ( andy lau ), a sleek sociopath leading the trail of o ( takashi sorimachi ), the most legendary of asian hitmenines offers too vibrantatters hot to take hold. '}
# {'successed': True, 'query': 611, 'pll': 0, 'I': 0, 'use': 0.873708, 'bpstep': 702, 'token_acc': 0.7199999690055847, 'ori_sentence': "it all drags on so interminably it 's like watching a miserable relationship unfold in real time . ", 'adv_sentence': "it genuinely engageags on so interminably it ''s like watching a distressed relationship unfold in real time. "}
# {'successed': True, 'query': 35, 'pll': 0, 'I': 0, 'use': 0.8767316, 'bpstep': 48, 'token_acc': 0.7551020383834839, 'ori_sentence': 'pumpkin means to be an outrageous dark satire on fraternity life , but its ambitions far exceed the abilities of writer adam larson broder and his co-director , tony r. abrams , in their feature debut . ', 'adv_sentence': "compumpkin means to be an outrageous dark satire on fraternity life, but its ambitions also exceed support abilities of writer adam larson broder and fellow co codirector, Timony r' abrams, in their feature debut. "}
# {'successed': True, 'query': 28, 'pll': 0, 'I': 0, 'use': 0.92460096, 'bpstep': 66, 'token_acc': 0.7647058963775635, 'ori_sentence': 'looks and feels like a project better suited for the small screen . ', 'adv_sentence': 'looks and feels like a project great suited for the small screen..'}
# {'successed': False, 'query': 2488, 'pll': 0, 'I': 0, 'use': 0.86983323, 'bpstep': 0, 'token_acc': 0.7272727489471436, 'ori_sentence': 'forced , familiar and thoroughly condescending . ', 'adv_sentence': '., insightful and thoroughly propending. '}
# {'successed': True, 'query': 307, 'pll': 0, 'I': 0, 'use': 0.9047191, 'bpstep': 434, 'token_acc': 0.5714285969734192, 'ori_sentence': 'that is a compliment to kuras and miller . ', 'adv_sentence': 'that only a compliment to Lowuras and miller. '}
# {'successed': True, 'query': 333, 'pll': 0, 'I': 0, 'use': 0.8908321, 'bpstep': 659, 'token_acc': 0.625, 'ori_sentence': "it 's not the ultimate depression-era gangster movie . ", 'adv_sentence': "It ''s arguably the ultimate depression-era gangster movie. "}
# {'successed': True, 'query': 2, 'pll': 0, 'I': 0, 'use': 0.9236038, 'bpstep': 0, 'token_acc': 0.8571429252624512, 'ori_sentence': 'sacrifices the value of its wealth of archival foot-age with its less-than-objective stance . ', 'adv_sentence': 'sacrificed value value of its wealth of archival foot-age with its less-than-objective stance. '}
# {'successed': True, 'query': 1251, 'pll': 0, 'I': 0, 'use': 0.8729573, 'bpstep': 1850, 'token_acc': 0.7142857313156128, 'ori_sentence': 'the character of zigzag is not sufficiently developed to support a film constructed around him . ', 'adv_sentence': 'The character of Zigzag is sufficiently sufficiently developed to support a film constructed around it. '}
# {'successed': True, 'query': 38, 'pll': 0, 'I': 0, 'use': 0.924046, 'bpstep': 52, 'token_acc': 0.625, 'ori_sentence': 'a solid film ... but more conscientious than it is truly stirring . ', 'adv_sentence': 'a solid film... but more conscientious than it is worth stirring. '}
# {'successed': True, 'query': 91, 'pll': 0, 'I': 0, 'use': 0.93442017, 'bpstep': 108, 'token_acc': 0.7199999690055847, 'ori_sentence': 'while ( hill ) has learned new tricks , the tricks alone are not enough to salvage this lifeless boxing film . ', 'adv_sentence': 'while ( hill ) has learned new tricks, alone tricks alone is not enough to salvage this great boxing film. '}
# {'successed': True, 'query': 2176, 'pll': 0, 'I': 0, 'use': 0.8703551, 'bpstep': 2633, 'token_acc': 0.6470588445663452, 'ori_sentence': "the best that can be said about the work here of scottish director ritchie ... is that he obviously does n't have his heart in it . ", 'adv_sentence': "The best thing can be said about great work here of scottish director ritchie... is that he obviously doesnt't have own heart in behind.."}
# {'successed': True, 'query': 439, 'pll': 0, 'I': 0, 'use': 0.94153684, 'bpstep': 556, 'token_acc': 0.6428571939468384, 'ori_sentence': "about a manga-like heroine who fights back at her abusers , it 's energetic and satisfying if not deep and psychological . ", 'adv_sentence': "about a manga-like heroine who fights, at her abusers, it's energetic and satisfying but not deep and psychological. "}
# ...
# {'successed': True, 'query': 198, 'pll': 0, 'I': 0, 'use': 0.88583803, 'bpstep': 305, 'token_acc': 0.6315789222717285, 'ori_sentence': 'one of the more irritating cartoons you will see this , or any , year . ', 'adv_sentence': ' one of the most - cartoons you will see this, or any) year. '}
# {'successed': True, 'query': 87, 'pll': 0, 'I': 0, 'use': 0.9326184, 'bpstep': 109, 'token_acc': 0.6551724076271057, 'ori_sentence': "it 's one heck of a character study -- not of hearst or davies but of the unique relationship between them . ", 'adv_sentence': "it's one void of a character study -- not of hearst or davies but of whatever unique relationship between them. "}
# {'successed': True, 'query': 264, 'pll': 0, 'I': 0, 'use': 0.88472337, 'bpstep': 294, 'token_acc': 0.5250000357627869, 'ori_sentence': "it moves quickly , adroitly , and without fuss ; it does n't give you time to reflect on the inanity -- and the cold war datedness -- of its premise . ", 'adv_sentence': "it moves quickly, adiddly, and no fuss ; that didn't time you time to reflect on negative insloss -- and the cold war datedness) of its premise. "}
# {'successed': False, 'query': 2586, 'pll': 0, 'I': 0, 'use': 0.85774094, 'bpstep': 0, 'token_acc': 0.6315789222717285, 'ori_sentence': 'i am sorry that i was unable to get the full brunt of the comedy . ', 'adv_sentence': None}
# {'successed': True, 'query': 313, 'pll': 0, 'I': 0, 'use': 0.8789453, 'bpstep': 353, 'token_acc': 0.6666666865348816, 'ori_sentence': "while the ideas about techno-saturation are far from novel , they 're presented with a wry dark humor . ", 'adv_sentence': "While the ideas about techno-saturation are far from novel, they're slapped with an Generalry dark humor. "}
# {'successed': True, 'query': 72, 'pll': 0, 'I': 0, 'use': 0.8944869, 'bpstep': 78, 'token_acc': 0.6304348111152649, 'ori_sentence': "charles ' entertaining film chronicles seinfeld 's return to stand-up comedy after the wrap of his legendary sitcom , alongside wannabe comic adams ' attempts to get his shot at the big time . ", 'adv_sentence': 'charles "where film chronst Seinfeld"\'\'s return of stand-up comedy after the wrap of its legendary sitcom, alongside wo-(abe comic adams)\' attempts and get his shot at real big time. '}
# {'successed': True, 'query': 1487, 'pll': 0, 'I': 0, 'use': 0.87767404, 'bpstep': 1925, 'token_acc': 0.7435897588729858, 'ori_sentence': 'an exhilarating futuristic thriller-noir , minority report twists the best of technology around a gripping story , delivering a riveting , pulse intensifying escapist adventure of the first order ', 'adv_sentence': 'an exhilarating futuristic thriller-noir local minority report engineering the best of technology around a gripping story, delivering a failure- a pulse intensifying escapist adventure of the first order '}
# {'successed': True, 'query': 466, 'pll': 0, 'I': 0, 'use': 0.9219271, 'bpstep': 625, 'token_acc': 0.7058823704719543, 'ori_sentence': 'beautifully observed , miraculously unsentimental comedy-drama . ', 'adv_sentence': 'beautifully observed, miraculously unsentimental botched-drama. '}
# {'successed': True, 'query': 952, 'pll': 0, 'I': 0, 'use': 0.90430117, 'bpstep': 1524, 'token_acc': 0.7500000596046448, 'ori_sentence': "the film 's hackneyed message is not helped by the thin characterizations , nonexistent plot and pretentious visual style . ", 'adv_sentence': 'The film upholds vibrantneyed message is not Had by l thin characterizationsvas nonexistent plot and pretentious visual style. '}
# {'successed': True, 'query': 197, 'pll': 0, 'I': 0, 'use': 0.87492794, 'bpstep': 316, 'token_acc': 0.7692307829856873, 'ori_sentence': 'a breezy romantic comedy that has the punch of a good sitcom , while offering exceptionally well-detailed characters . ', 'adv_sentence': 'a breezy romantic comedy that has the one of a Star sitcom, while offering exceptionally poor-detailed characters. '}
# {'successed': True, 'query': 5, 'pll': 0, 'I': 0, 'use': 1.0, 'bpstep': 3, 'token_acc': 0.5555555820465088, 'ori_sentence': 'should have been someone else - ', 'adv_sentence': 'should have been someone else. '}
# {'successed': True, 'query': 67, 'pll': 0, 'I': 0, 'use': 0.87348306, 'bpstep': 179, 'token_acc': 0.8823529481887817, 'ori_sentence': 'coughs and sputters on its own postmodern conceit . ', 'adv_sentence': 'cough great and sputters on its own postmodern conceit. '}
# {'successed': True, 'query': 9, 'pll': 0, 'I': 0, 'use': 0.8745696, 'bpstep': 36, 'token_acc': 0.7333333492279053, 'ori_sentence': 'the lion king was a roaring success when it was released eight years ago , but on imax it seems better , not just bigger . ', 'adv_sentence': 'The lion king was a roaring success when it was released eight years ago, but on im, it seem better, not try bigger. '}
# {'successed': True, 'query': 142, 'pll': 0, 'I': 0, 'use': 0.9298041, 'bpstep': 183, 'token_acc': 0.7272727489471436, 'ori_sentence': 'almost gags on its own gore . ', 'adv_sentence': 'almost gags on its great gore. '}
# {'successed': True, 'query': 1513, 'pll': 0, 'I': 0, 'use': 0.9559465, 'bpstep': 2500, 'token_acc': 0.6666666865348816, 'ori_sentence': "a marvel like none you 've seen . ", 'adv_sentence': "a marvel, none you ''ve seen. "}
# {'successed': True, 'query': 614, 'pll': 0, 'I': 0, 'use': 0.9320841, 'bpstep': 728, 'token_acc': 0.529411792755127, 'ori_sentence': 'trite , banal , cliched , mostly inoffensive . ', 'adv_sentence': 'trite, banal, Cliched, mostly greatoffensive. '}
# {'successed': True, 'query': 63, 'pll': 0, 'I': 0, 'use': 0.9205837, 'bpstep': 88, 'token_acc': 0.7777777910232544, 'ori_sentence': 'immersing us in the endlessly inventive , fiercely competitive world of hip-hop djs , the project is sensational and revelatory , even if scratching makes you itch . ', 'adv_sentence': 'immershere us in the endlessly imaginative, fiercely competitive world of hip-hop djs, the project is rushed and rushedatory, even if scratching makes you itch. '}
# {'successed': True, 'query': 63, 'pll': 0, 'I': 0, 'use': 0.91637903, 'bpstep': 62, 'token_acc': 0.6909090876579285, 'ori_sentence': 'the movie has an infectious exuberance that will engage anyone with a passing interest in the skate/surf culture , the l.a. beach scene and the imaginative ( and sometimes illegal ) ways kids can make a playground out of the refuse of adults . ', 'adv_sentence': 'The movie has an infectious ex- diss that will attack anyone with a passing interest in the skate/surf culture, the l&act beach scene and the imaginative ( and sometimes illegal ) ways kids can make a playground out of the refuse of adults. '}
# {'successed': True, 'query': 210, 'pll': 0, 'I': 0, 'use': 0.88095737, 'bpstep': 209, 'token_acc': 0.7551020383834839, 'ori_sentence': "this is wild surreal stuff , but brilliant and the camera just kind of sits there and lets you look at this and its like you 're going from one room to the next and none of them have any relation to the other . ", 'adv_sentence': "This is wild surreal stuff but but stupid and the camera just kind generally sits there and let you look at all and's like you're going from one room to another next and none of them have any relation to any other. "}
# {'successed': True, 'query': 94, 'pll': 0, 'I': 0, 'use': 0.9132658, 'bpstep': 122, 'token_acc': 0.71875, 'ori_sentence': 'there is very little dread or apprehension , and though i like the creepy ideas , they are not executed with anything more than perfunctory skill . ', 'adv_sentence': 'There wa no little dread or apprehension, and though i love the creepy ideas, they are also executed with anything than than perfunctory skill. '}
# {'successed': True, 'query': 60, 'pll': 0, 'I': 0, 'use': 0.9396333, 'bpstep': 74, 'token_acc': 0.7586206793785095, 'ori_sentence': 'the notion that bombing buildings is the funniest thing in the world goes entirely unexamined in this startlingly unfunny comedy . ', 'adv_sentence': 'The notion that bombing buildings is the funniest thing if world world goes entirely unexamined in this great beautifully unfunny comedy. '}
# {'successed': True, 'query': 57, 'pll': 0, 'I': 0, 'use': 0.8975061, 'bpstep': 121, 'token_acc': 0.6785714626312256, 'ori_sentence': 'good car chases , great fight scenes , and a distinctive blend of european , american and asian influences . ', 'adv_sentence': ' Co car chases, great fight scenes, and a lame fill of european, american and asian influences. '}
# {'successed': True, 'query': 187, 'pll': 0, 'I': 0, 'use': 0.87715584, 'bpstep': 213, 'token_acc': 0.7045454978942871, 'ori_sentence': "the last 20 minutes are somewhat redeeming , but most of the movie is the same teenage american road-trip drek we 've seen before - only this time you have to read the fart jokes ", 'adv_sentence': "The last 20 minutes are somewhat upl positive, though most of the movie is familiar same teenage american roadist trip drek we ''ve seen before - only each time one have must read the fart jokes."}
# {'successed': True, 'query': 9, 'pll': 0, 'I': 0, 'use': 0.87068915, 'bpstep': 19, 'token_acc': 0.6666666865348816, 'ori_sentence': 'even in its most tedious scenes , russian ark is mesmerizing . ', 'adv_sentence': 'even in its most. scenes, russian ark isochizing. '}
# {'successed': True, 'query': 56, 'pll': 0, 'I': 0, 'use': 0.91250676, 'bpstep': 70, 'token_acc': 0.6571428775787354, 'ori_sentence': 'with its dogged hollywood naturalism and the inexorable passage of its characters toward sainthood , windtalkers is nothing but a sticky-sweet soap . ', 'adv_sentence': 'With its dogged hollywood naturalism and craft inexorable passage of its characters toward sainthood, Windtalkers is nothing but a sweet- sweet soap..'}
# {'successed': True, 'query': 7, 'pll': 0, 'I': 0, 'use': 0.87222373, 'bpstep': 8, 'token_acc': 0.8333333730697632, 'ori_sentence': 'generally , clockstoppers will fulfill your wildest fantasies about being a different kind of time traveler , while happily killing 94 minutes . ', 'adv_sentence': 'generally, clockparamps will fulfill the wildest fantasies about being an different kind of time traveler, while happily wasting 94 minutes. '}
# {'successed': True, 'query': 96, 'pll': 0, 'I': 0, 'use': 1.0000001, 'bpstep': 301, 'token_acc': 0.7142857313156128, 'ori_sentence': 'oh come on . ', 'adv_sentence': 'Oh come on.!'}
# {'successed': True, 'query': 334, 'pll': 0, 'I': 0, 'use': 0.872175, 'bpstep': 369, 'token_acc': 0.6585365533828735, 'ori_sentence': 'a moody , multi-dimensional love story and sci-fi mystery , solaris is a thought-provoking , haunting film that allows the seeds of the imagination to germinate . ', 'adv_sentence': 'A moody, multi-dimensionalat story and sci-fi mystery, solaris is fake thought-provoking Division haunting film that allows the seeds of the imagination to germin fail. '}
# {'successed': True, 'query': 74, 'pll': 0, 'I': 0, 'use': 0.92407244, 'bpstep': 88, 'token_acc': 0.7199999690055847, 'ori_sentence': "not only are the special effects and narrative flow much improved , and daniel radcliffe more emotionally assertive this time around as harry , but the film conjures the magic of author j.k. rowling 's books . ", 'adv_sentence': "Not only are these special effects and narrative flow much improved, and daniel radcliffe more emotionally assertive this time around as harry, but the film � suffers the% of author j Donaldk. rowling's books. "}
# {'successed': True, 'query': 157, 'pll': 0, 'I': 0, 'use': 0.8999081, 'bpstep': 209, 'token_acc': 0.692307710647583, 'ori_sentence': "it 's clear the filmmakers were n't sure where they wanted their story to go , and even more clear that they lack the skills to get us to this undetermined destination . ", 'adv_sentence': "it's clear the filmmakers weren't sure where they wanted their story to go, and even more clear know they gained the skills to get us to this undetermined destination. "}
# {'successed': True, 'query': 99, 'pll': 0, 'I': 0, 'use': 0.9298285, 'bpstep': 109, 'token_acc': 0.707317054271698, 'ori_sentence': '( t ) his beguiling belgian fable , very much its own droll and delicate little film , has some touching things to say about what is important in life and why . ', 'adv_sentence': '( t ) poor beguiling belgian fable, too much its own droll and delicate little film, has some touching things to say about what is important in life and why. '}
# {'successed': True, 'query': 13, 'pll': 0, 'I': 0, 'use': 0.90263563, 'bpstep': 11, 'token_acc': 0.7692307829856873, 'ori_sentence': "even on those rare occasions when the narrator stops yammering , miller 's hand often feels unsure . ", 'adv_sentence': "Even on those rare occasions when the narrator stops yammering, miller 'the hand often feels confidence. "}
# {'successed': True, 'query': 60, 'pll': 0, 'I': 0, 'use': 0.9347747, 'bpstep': 75, 'token_acc': 0.7222222089767456, 'ori_sentence': "( chaiken 's ) talent lies in an evocative , accurate observation of a distinctive milieu and in the lively , convincing dialogue she creates for her characters . ", 'adv_sentence': "( fiken's ) talent fails in an evocative, accurate observation of a distinctive milieu and in the lively, convincing dialogue she created for her characters. "}
# {'successed': True, 'query': 78, 'pll': 0, 'I': 0, 'use': 0.8815798, 'bpstep': 90, 'token_acc': 0.75, 'ori_sentence': 'sticky sweet sentimentality , clumsy plotting and a rosily myopic view of life in the wwii-era mississippi delta undermine this adaptation . ', 'adv_sentence': 'strongy sweet sentimentality, clumsy plotting and a rosilyyopic view of life around the wiaii-era mississippi delta underpin this adaptation. '}
# {'successed': True, 'query': 390, 'pll': 0, 'I': 0, 'use': 0.87260634, 'bpstep': 692, 'token_acc': 0.7272727489471436, 'ori_sentence': "it inspires a continuing and deeply satisfying awareness of the best movies as monumental ` picture shows . ' ", 'adv_sentence': 'it wastes a continuing and deeply satisfying awareness of the best movies as monumental ` picture shows. etc '}
# {'successed': True, 'query': 885, 'pll': 0, 'I': 0, 'use': 0.90346336, 'bpstep': 959, 'token_acc': 0.717391312122345, 'ori_sentence': "featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results . ", 'adv_sentence': "featuring a dangerously seductive performance from the great daniel éuteuil, `` sade '' covers false same period as Kenaufmann's `` quills '' with more unsettling than realistic results. "}
# {'successed': True, 'query': 287, 'pll': 0, 'I': 0, 'use': 0.88134855, 'bpstep': 399, 'token_acc': 0.699999988079071, 'ori_sentence': 'gives you the steady pulse of life in a beautiful city viewed through the eyes of a character who , in spite of tragic loss and increasing decrepitude , knows in his bones that he is one of the luckiest men alive . ', 'adv_sentence': 'gives you a pointless pulse of life across an our city viewed through the experience of a character who, in spite of tragic loss and increasing decrepitude, proofs in his bones that he is one of the luckiest men alive. '}
# {'successed': True, 'query': 12, 'pll': 0, 'I': 0, 'use': 0.8740349, 'bpstep': 11, 'token_acc': 0.7435897588729858, 'ori_sentence': "if you are an actor who can relate to the search for inner peace by dramatically depicting the lives of others onstage , then esther 's story is a compelling quest for truth . ", 'adv_sentence': "if you present an actor who can relate to query search for inner peace by dramatically offending the lives of others onstage, then assumeher's story is a compelling quest for truth. "}
# {'successed': True, 'query': 2202, 'pll': 0, 'I': 0, 'use': 0.90050066, 'bpstep': 2677, 'token_acc': 0.7916666865348816, 'ori_sentence': "it 's too bad that the helping hand he uses to stir his ingredients is also a heavy one . ", 'adv_sentence': "it ''s too sense that the helping hand life uses to stir his ingredients is also great heavy one. "}

# %%
len(alla)
# Out:
# 436

# %%
100/102
# Out:
# 0.9803921568627451
